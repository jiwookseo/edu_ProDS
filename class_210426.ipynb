# %%
import os
os.listdir("dataset")
# Out:
# ['iris_xlsx.csv',
#  'bank.csv',
#  'classification_data_01.csv',
#  'bike_rental.csv',
#  'linear_regression_01.csv',
#  'traffic_accident.txt',
#  'bike_weather.csv',
#  'class_scores.csv',
#  'diamonds.csv',
#  'iris_missing.csv',
#  'elec_load.csv',
#  'logistic_regression_01.csv',
#  'join_list.csv',
#  'bike.csv',
#  'AWS_sample.txt',
#  'join_room.csv',
#  'iris_xlsx.xlsx',
#  'diabetes.csv',
#  'bike.json',
#  'rating_chocobar.csv']

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("dataset/bike.csv")
df
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %%
df = pd.read_csv("dataset/AWS_sample.txt")
df.head(2)
# Out:
#            AWS_ID#TM#TA#Wind#X.
# 0  108#2016-07-01 00#24.2#2.3#=
# 1  108#2016-07-01 01#24.3#2.3#=

# %%
df = pd.read_csv("dataset/AWS_sample.txt", sep="#")
df.head(2)
# Out:
#    AWS_ID             TM    TA  Wind X.
# 0     108  2016-07-01 00  24.2   2.3  =
# 1     108  2016-07-01 01  24.3   2.3  =

# %%
elec = pd.read_csv("dataset/elec_load.csv")
print(elec.shape)
print(elec.X1HR.mean())
elec_2009 = elec.loc[elec["YEAR"] == 2009]
print(len(elec_2009))
# Out:
# (3546, 27)
# 46606.40778341793
# 365
#       YEAR  MONTH  DAY   X1HR   X2HR   X3HR   X4HR   X5HR   X6HR   X7HR  ...  \
# 731   2010      1    1  44836  43190  41568  40160  38968  38410  37867  ...
# 732   2010      1    2  42703  41183  39859  38594  38258  38737  39863  ...
# 733   2010      1    3  47969  45993  44537  43448  42924  42977  43812  ...
# 734   2010      1    4  49617  47626  46207  45062  44517  44574  45267  ...
# 735   2010      1    5  51130  49531  48229  46993  46211  46221  46868  ...
# ...    ...    ...  ...    ...    ...    ...    ...    ...    ...    ...  ...
# 1091  2010     12   27  48186  45777  44474  43861  44114  44789  45905  ...
# 1092  2010     12   28  50218  48237  46937  46203  46306  46801  47908  ...
# 1093  2010     12   29  52732  51015  49833  48742  48271  48366  49103  ...
# 1094  2010     12   30  51396  49577  48258  47017  46379  46181  46178  ...
# 1095  2010     12   31  47702  46085  44586  43466  42811  42439  41630  ...
#
# ...

# %%
elec_2009
# Out:
#      YEAR  MONTH  DAY   X1HR   X2HR   X3HR   X4HR   X5HR   X6HR   X7HR  ...  \
# 366  2009      1    1  42897  41499  39727  38092  36863  36109  35488  ...
# 367  2009      1    2  40234  38974  36992  35632  34604  34328  34004  ...
# 368  2009      1    3  40302  38632  37067  35686  35042  35220  36059  ...
# 369  2009      1    4  45115  43287  41729  40503  39726  39805  40508  ...
# 370  2009      1    5  46384  44650  43304  41956  41217  41147  41884  ...
# ..    ...    ...  ...    ...    ...    ...    ...    ...    ...    ...  ...
# 726  2009     12   27  51126  49540  48312  47091  46243  45645  46680  ...
# 727  2009     12   28  51460  50026  48679  47288  46317  46259  47045  ...
# 728  2009     12   29  51066  49298  48004  46660  45897  45718  46283  ...
# 729  2009     12   30  50488  48708  47330  45886  44910  44570  45033  ...
# 730  2009     12   31  48339  46788  45416  44057  42966  42357  42183  ...
#
# ...
