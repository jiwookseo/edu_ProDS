# %% [markdown]
# # 다음 문제를 풀이하시오

# %%
import pandas as pd
pd.__version__
# Out:
# '1.2.3'

# %% [markdown]
# ### Q1. 비어있는 데이터프레임 df_0을 생성하시오.

# %%
df_0 = pd.DataFrame()
df_0
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Q2. 딕셔너리를 활용하여 변수가 2개, 원소가 6개인 데이터프레임 df1를 생성하시오.
# ※ 변수명과 원소 값은 직접 임의로 지정

# %%
df_1 = pd.DataFrame([[0,1], [2,3], [4,5]], columns=["co11", "col2"])
df_1
# Out:
#    co11  col2
# 0     0     1
# 1     2     3
# 2     4     5

# %% [markdown]
# ### Q3. NumPy의 array 생성 방법을 활용하여 변수가 2개, 원소가 6개인 데이터프레임 df2를 생성하시오.
# ※ 변수명과 원소 값은 직접 임의로 지정

# %%
import numpy as np
df_2 = pd.DataFrame(np.arange(6).reshape(3,2), columns=["co11", "col2"])
df_2
# Out:
#    co11  col2
# 0     0     1
# 1     2     3
# 2     4     5
