# %% [markdown]
# # 다음 문제를 풀이하시오

# %% [markdown]
# ### Q1. Pandas, Scipy의 stats 모듈을 불러오시오.

# %%
import pandas as pd
from scipy import stats

# %% [markdown]
# ### Q2. "bike.csv" 파일을 불러와서 df 객체에 저장하시오.

# %%
df = pd.read_csv("../dataset/bike.csv")

# %% [markdown]
# ### Q3. "season" 이 2인 "registered" 값 전체를 reg_s2 객체에 저장하시오.

# %%
reg_s2 = df.loc[df.season == 2, "registered"]

# %% [markdown]
# ### Q4. "season" 이 4인 "registered" 값 전체를 reg_s4 객체에 저장하시오.

# %%
reg_s4 = df.loc[df.season == 4, "registered"]

# %% [markdown]
# ### Q5. reg_s2 객체와 reg_s4 객체를 독립 2표본 t검정을 실시하고 그 결과를 확인하시오.

# %%
stat, p = stats.ttest_ind(reg_s2, reg_s4)
print(stat, p)
# Out:
# -0.6188434510636714 0.5360452879439642

# %% [markdown]
# p-value가 0.53..으로 유의수준5%(0.05) 기준으로 p-value가 유의수준보다 더 크기 떄문에 귀무가설을 기각하지 못함. 즉, 두 집단의 평균이 서로 같은 것이나 다름 없음.
