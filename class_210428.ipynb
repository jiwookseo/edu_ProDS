# %%
import pandas as pd
import numpy as np

# %%
bike = pd.read_csv("dataset/bike.csv")
bike.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
bike.sample(n=2)
# Out:
#                  datetime  season  holiday  workingday  weather   temp  atemp  \
# 7846  2012-06-07 07:00:00       2        0           1        1  20.50  24.24
# 5285  2011-12-14 07:00:00       4        0           1        1  11.48  15.91
#
#       humidity  windspeed  casual  registered  count
# 7846        82    11.0014      20         506    526
# 5285        75     0.0000       4         243    247

# %%
np.random.seed(3)
bike.sample(n=2)
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 6198  2012-02-14 12:00:00       1        0           1        2  12.30
# 8947  2012-08-15 04:00:00       3        0           1        1  26.24
#
#        atemp  humidity  windspeed  casual  registered  count
# 6198  14.395        52    15.0013      10         162    172
# 8947  28.790        83     7.0015       0           4      4

# %%
bike.sample(n=2, random_state=123)
# Out:
#                  datetime  season  holiday  workingday  weather   temp  atemp  \
# 6495  2012-03-07 21:00:00       1        0           1        1  18.04  21.97
# 7050  2012-04-12 03:00:00       2        0           1        1  13.12  15.15
#
#       humidity  windspeed  casual  registered  count
# 6495        62    16.9979      11         177    188
# 7050        61    16.9979       2           3      5

# %%
iris = pd.read_csv("dataset/iris_xlsx.csv")

# %%
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.corr()
# Out:
#               Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# Sepal.Length      1.000000    -0.117570      0.871754     0.817941
# Sepal.Width      -0.117570     1.000000     -0.428440    -0.366126
# Petal.Length      0.871754    -0.428440      1.000000     0.962865
# Petal.Width       0.817941    -0.366126      0.962865     1.000000

# %%
iris.corr(method="pearson") #default: pearson
# Out:
#               Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# Sepal.Length      1.000000    -0.117570      0.871754     0.817941
# Sepal.Width      -0.117570     1.000000     -0.428440    -0.366126
# Petal.Length      0.871754    -0.428440      1.000000     0.962865
# Petal.Width       0.817941    -0.366126      0.962865     1.000000

# %%
iris.corr().round(2)
# Out:
#               Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# Sepal.Length          1.00        -0.12          0.87         0.82
# Sepal.Width          -0.12         1.00         -0.43        -0.37
# Petal.Length          0.87        -0.43          1.00         0.96
# Petal.Width           0.82        -0.37          0.96         1.00

# %%
from scipy.stats import pearsonr #pearosn 상관분석
from scipy.stats import kendalltau #kendall 상관분석
from scipy.stats import spearmanr #spearman 상관분석

# %%
df = pd.DataFrame([["A", 3], ["C", 1], ["B", 2]], columns=["class", "value"])
df
# Out:
#   class  value
# 0     A      3
# 1     C      1
# 2     B      2

# %%
df.sort_values(by="class")
# Out:
#   class  value
# 0     A      3
# 2     B      2
# 1     C      1

# %%
df.sort_values(by="class", ascending=False)
# Out:
#   class  value
# 1     C      1
# 2     B      2
# 0     A      3

# %%
df_1 = bike.head()
df_2 = bike.tail()
df_bind = pd.concat([df_1, df_2])
df_bind.shape
# Out:
# (10, 12)

# %%
df_bind
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# 0      14.395        81     0.0000       3          13     16
# ...

# %%
pd.concat([df_1, df_2], axis = 1)
# Out:
#                   datetime  season  holiday  workingday weather  temp   atemp  \
# 0      2011-01-01 00:00:00     1.0      0.0         0.0     1.0  9.84  14.395
# 1      2011-01-01 01:00:00     1.0      0.0         0.0     1.0  9.02  13.635
# 2      2011-01-01 02:00:00     1.0      0.0         0.0     1.0  9.02  13.635
# 3      2011-01-01 03:00:00     1.0      0.0         0.0     1.0  9.84  14.395
# 4      2011-01-01 04:00:00     1.0      0.0         0.0     1.0  9.84  14.395
# 10881                  NaN     NaN      NaN         NaN     NaN   NaN     NaN
# 10882                  NaN     NaN      NaN         NaN     NaN   NaN     NaN
# 10883                  NaN     NaN      NaN         NaN     NaN   NaN     NaN
# 10884                  NaN     NaN      NaN         NaN     NaN   NaN     NaN
# 10885                  NaN     NaN      NaN         NaN     NaN   NaN     NaN
#
#        humidity  windspeed  casual  ...  holiday  workingday weather   temp  \
# ...

# %%
pd.concat([df_1, df_2.reset_index(drop=True)], axis = 1)
# Out:
#               datetime  season  holiday  workingday weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0       1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0       1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0       1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0       1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0       1  9.84  14.395
#
#    humidity  windspeed  casual  ...  holiday  workingday weather   temp  \
# 0        81        0.0       3  ...        0           1       1  15.58
# 1        80        0.0       8  ...        0           1       1  14.76
# 2        80        0.0       5  ...        0           1       1  13.94
# 3        75        0.0       3  ...        0           1       1  13.94
# 4        75        0.0       0  ...        0           1       1  13.12
#
#     atemp  humidity  windspeed  casual  registered  count
# ...

# %%
# bike["season_1"] = np.where(bike["season"] == 1, 1, 0)
bike["season_1"] = (bike["season"] == 1).astype(int)
bike["season_1"]
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 10881    0
# 10882    0
# 10883    0
# 10884    0
# 10885    0
# Name: season_1, Length: 10886, dtype: int64

# %%
df_dum = pd.get_dummies(bike.iloc[:, 1:], columns=["season"])
df_dum.loc[1322:1323]
# Out:
#       holiday  workingday  weather   temp   atemp  humidity  windspeed  \
# 1322        0           0        1  15.58  19.695        40    19.9995
# 1323        0           1        3  10.66  12.880       100    11.0014
#
#       casual  registered  count  season_1  season_1  season_2  season_3  \
# 1322      13          37     50         1         1         0         0
# 1323       0           6      6         0         0         1         0
#
#       season_4
# 1322         0
# 1323         0

# %%
df_dum = pd.get_dummies(bike.iloc[:, 1:], columns=["season"], drop_first=True)
df_dum.loc[1322:1323]
# Out:
#       holiday  workingday  weather   temp   atemp  humidity  windspeed  \
# 1322        0           0        1  15.58  19.695        40    19.9995
# 1323        0           1        3  10.66  12.880       100    11.0014
#
#       casual  registered  count  season_1  season_2  season_3  season_4
# 1322      13          37     50         1         0         0         0
# 1323       0           6      6         0         1         0         0

# %%
bike["season"].unique()
# Out:
# array([1, 2, 3, 4])

# %%
bike["season"].value_counts()
# Out:
# 4    2734
# 2    2733
# 3    2733
# 1    2686
# Name: season, dtype: int64

# %%
pd.crosstab(bike["season"], bike["holiday"])
# Out:
# holiday     0   1
# season
# 1        2615  71
# 2        2685  48
# 3        2637  96
# 4        2638  96

# %%
dia = pd.read_csv("dataset/diamonds.csv")

# %%
dia.cut.value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
dia.cut.value_counts(normalize=True)
# Out:
# Ideal        0.399537
# Premium      0.255673
# Very Good    0.223990
# Good         0.090953
# Fair         0.029848
# Name: cut, dtype: float64

# %%
dia.cut.value_counts(normalize=True).reset_index().round(2)
# Out:
#        index   cut
# 0      Ideal  0.40
# 1    Premium  0.26
# 2  Very Good  0.22
# 3       Good  0.09
# 4       Fair  0.03

# %%
pd.crosstab(dia["cut"], dia['color'])
# Out:
# color         D     E     F     G     H     I    J
# cut
# Fair        163   224   312   314   303   175  119
# Good        662   933   909   871   702   522  307
# Ideal      2834  3903  3826  4884  3115  2093  896
# Premium    1603  2337  2331  2924  2360  1428  808
# Very Good  1513  2400  2164  2299  1824  1204  678

# %%
pd.crosstab(dia["cut"], dia['color'], normalize=True)
# Out:
# color             D         E         F         G         H         I  \
# cut
# Fair       0.003022  0.004153  0.005784  0.005821  0.005617  0.003244
# Good       0.012273  0.017297  0.016852  0.016148  0.013014  0.009677
# Ideal      0.052540  0.072358  0.070931  0.090545  0.057749  0.038802
# Premium    0.029718  0.043326  0.043215  0.054208  0.043752  0.026474
# Very Good  0.028050  0.044494  0.040119  0.042621  0.033815  0.022321
#
# color             J
# cut
# Fair       0.002206
# Good       0.005692
# Ideal      0.016611
# Premium    0.014980
# Very Good  0.012570

# %%
pd.crosstab(dia["cut"], dia['color'], normalize=0)
# Out:
# color             D         E         F         G         H         I  \
# cut
# Fair       0.101242  0.139130  0.193789  0.195031  0.188199  0.108696
# Good       0.134937  0.190175  0.185283  0.177538  0.143090  0.106400
# Ideal      0.131502  0.181105  0.177532  0.226625  0.144541  0.097118
# Premium    0.116235  0.169458  0.169023  0.212022  0.171126  0.103546
# Very Good  0.125228  0.198643  0.179109  0.190283  0.150968  0.099652
#
# color             J
# cut
# Fair       0.073913
# Good       0.062576
# Ideal      0.041576
# Premium    0.058589
# Very Good  0.056117

# %%
pd.crosstab(dia["cut"], dia['color'], normalize=1)
# Out:
# color             D         E         F         G         H         I  \
# cut
# Fair       0.024059  0.022864  0.032698  0.027807  0.036488  0.032276
# Good       0.097712  0.095233  0.095263  0.077134  0.084538  0.096274
# Ideal      0.418303  0.398387  0.400964  0.432519  0.375120  0.386020
# Premium    0.236605  0.238542  0.244288  0.258944  0.284200  0.263371
# Very Good  0.223321  0.244973  0.226787  0.203595  0.219653  0.222058
#
# color             J
# cut
# Fair       0.042379
# Good       0.109330
# Ideal      0.319088
# Premium    0.287749
# Very Good  0.241453

# %%
dia_sub = dia.loc[:5, "x":]
dia_sub["obs"] = dia_sub.index
dia_sub
# Out:
#       x     y     z  obs
# 0  3.95  3.98  2.43    0
# 1  3.89  3.84  2.31    1
# 2  4.05  4.07  2.31    2
# 3  4.20  4.23  2.63    3
# 4  4.34  4.35  2.75    4
# 5  3.94  3.96  2.48    5

# %%
dia_sub.melt(id_vars="obs").head()
# Out:
#    obs variable  value
# 0    0        x   3.95
# 1    1        x   3.89
# 2    2        x   4.05
# 3    3        x   4.20
# 4    4        x   4.34

# %%
elec = pd.read_csv("dataset/elec_load.csv")
elec.head()
# Out:
#    YEAR  MONTH  DAY   X1HR   X2HR   X3HR   X4HR   X5HR   X6HR   X7HR  ...  \
# 0  2008      1    1  39638  37682  35801  34154  33068  32529  31982  ...
# 1  2008      1    2  37425  35239  33568  32171  31616  31725  32575  ...
# 2  2008      1    3  40757  38681  37047  35732  34912  34922  35563  ...
# 3  2008      1    4  40220  38434  36832  35521  34728  34436  34299  ...
# 4  2008      1    5  39056  37208  35688  34481  33979  34261  35315  ...
#
#    X15HR  X16HR  X17HR  X18HR  X19HR  X20HR  X21HR  X22HR  X23HR  X24HR
# 0  28147  28313  28683  30921  32879  33038  34031  34684  37444  38160
# 1  38213  38132  38399  39796  40810  39980  40084  39630  42008  42150
# 2  37355  36776  36478  37221  38481  38074  38606  38596  41439  41521
# 3  32095  31985  32396  34213  36238  36424  37282  37525  40055  40232
# 4  42113  41734  42063  43370  44454  43408  43052  42300  44603  44500
#
# [5 rows x 27 columns]

# %%
elec_melt = elec.melt(id_vars=["YEAR", "MONTH", "DAY"])
elec_melt.head()
# Out:
#    YEAR  MONTH  DAY variable  value
# 0  2008      1    1     X1HR  39638
# 1  2008      1    2     X1HR  37425
# 2  2008      1    3     X1HR  40757
# 3  2008      1    4     X1HR  40220
# 4  2008      1    5     X1HR  39056

# %%
# elec_pivot = elec_melt.pivot_table(index=["YEAR", "MONTH", "DAY"], columns="variable", values="value").reset_index()
elec_pivot = elec_melt.pivot_table(index="YEAR", columns="variable", values="value", aggfunc="mean").reset_index()
elec_pivot
# Out:
# variable  YEAR         X10HR         X11HR         X12HR         X13HR  \
# 0         2008  39788.428962  40600.827869  40916.469945  38637.887978
# 1         2009  42610.646575  43469.205479  43864.104110  41497.271233
# 2         2010  44840.276712  45726.734247  46006.947945  43512.495890
# 3         2011  47613.717808  48578.904110  48764.164384  46159.583562
# 4         2012  49714.696721  50773.576503  50964.663934  48267.420765
# 5         2013  51368.298630  52421.939726  52532.323288  49768.786301
# 6         2014  56277.783562  57365.693151  57473.049315  54515.805479
# 7         2015  59055.873973  60020.224658  60026.528767  57006.676712
# 8         2016  60616.969945  61501.349727  61454.144809  58450.161202
# 9         2017  62120.693798  62868.577519  62797.116279  60075.104651
#
# variable         X14HR         X15HR         X16HR         X17HR  \
# 0         39986.907104  40649.508197  40379.448087  40368.475410
# ...

# %%
elec_melt.groupby(["YEAR", "variable"])["value"].mean().reset_index().head()
# Out:
#    YEAR variable         value
# 0  2008    X10HR  39788.428962
# 1  2008    X11HR  40600.827869
# 2  2008    X12HR  40916.469945
# 3  2008    X13HR  38637.887978
# 4  2008    X14HR  39986.907104

# %%
bike["datetime"] = pd.to_datetime(bike.datetime)
bike["wday"] = bike.datetime.dt.dayofweek
bike["month"] = bike.datetime.dt.month
bike["hour"] = bike.datetime.dt.hour
bike.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  season_1  wday  month  hour
# 0        81        0.0       3          13     16         1     5      1     0
# 1        80        0.0       8          32     40         1     5      1     1
# 2        80        0.0       5          27     32         1     5      1     2
# 3        75        0.0       3          10     13         1     5      1     3
# 4        75        0.0       0           1      1         1     5      1     4
